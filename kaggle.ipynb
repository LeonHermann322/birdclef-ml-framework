# %% [markdown]
# ## Notebook to execute our framework with the kaggle gpus

# %% [markdown]
# QuickStart:
# 1. Add github_token to Kaggle Secrets
# 2. Add Competition Dataset to inputs

# %%
import sys
import os

# %%
# if desired 
#from kaggle_secrets import UserSecretsClient
#user_secrets = UserSecretsClient()
#key = user_secrets.get_secret("wandb_key")
#!wandb login $key

# %%
from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()
key = user_secrets.get_secret("github_token")

# !git clone https://{key}@github.com/LeonHermann322/birdclef-ml-framework.git

# %%
dirpath_to_modules = "/kaggle/working/birdclef-ml-framework"
sys.path.append(dirpath_to_modules)
os.chdir("birdclef-ml-framework")

# %%
dataset_path = "/kaggle/input/competitions/birdclef-2026"

# %%
# !python run.py --experiment_id=mnist --use_cuda=false --hidden_sizes="[64]" #double execute to ignore config generation
# !python run.py --experiment_id=mnist --use_cuda=false --hidden_sizes="[64]"
